# %% [markdown]
# # Link to reach Anna University Journal lists

# %%
URL1 = "https://cfr.annauniv.edu/research/annexure-1-journals.php"
URL2 = "https://cfr.annauniv.edu/research/annexure-2-journals.php"

# %% [markdown]
# ## Including necessary packages

# %%
import requests
import lxml.html as lh
import pandas as pd
import urllib.request
import threading
from bs4 import BeautifulSoup as BS
import multiprocessing
import time
from joblib import Parallel, delayed

# %%
class WS:
    def __init__(self,Link=None):
        self.Link = Link
        self.URL  = 'https://www.scimagojr.com/journalsearch.php?q='
        self.num_cores = multiprocessing.cpu_count()
    def Parsing(self):
        '''Parsing of Anna university Annexture table'''
        Soup  = BS(requests.get(self.Link).content,'html.parser')
        Table = Soup.find('table',{"class":"myTable"})
        self.Table_Data = []
        for row in Table.find_all('tr'):
            tmp = []
            column = row.find_all('td')
            for index in range(len(column)):
                tmp.append(column[index].text.strip())
            self.Table_Data.append(tmp)
        self.Table_Data = pd.DataFrame(self.Table_Data)
        return self.Table_Data
    def clean(self):
        """ Cleaning of Data Frame by rename column name and removing certain indexes"""
        self.Table_Data.rename(columns = self.Table_Data.iloc[2],inplace=True)
        self.Table_Data =  self.Table_Data.drop(labels=[0,1,2],axis = 0)
        return self.Table_Data
    def extraction(self):
        '''Extraction of ISSN and modifing DataFrame with added SCOPE of the corresponding table'''
        self.ISSN = self.Table_Data['ISSN']
        self.ISSN = [i.split('\n')[0] for i in self.ISSN]
        self.Link = [self.URL+i for i in self.ISSN]
    def Link_Parsing(self,j,Link):
        try:
            response = urllib.request.urlopen(Link).read()
            soup = BS(response,'html.parser')
            print(j,":->")
            return 'https://www.scimagojr.com/'+soup.find('div', class_='search_results').a['href']
            
        except:
            print(j,":-(")
            return None
    def Scope_Parsing(self,j,url):
        try:
            response = urllib.request.urlopen(link).read()
            soup = BS(response,'html.parser')
            print(j,":->")
            return(str(soup.find('div', class_='fullwidth').contents[2]))
            

        except:
          #print(url)
          #Notaccess.append(url)
          print(j,":-(")
          return (None)
          
    def link_go(self):
        self.Link1 = Parallel(n_jobs=self.num_cores)(delayed(self.Link_Parsing)(j,i) for j,i in enumerate(self.Link))
        
    def scope_go(self):
        self.scope = Parallel(n_jobs=self.num_cores)(delayed(self.Scope_Parsing)(j,i) for j,i in enumerate(self.Link1))

# %%
T = WS(URL1)
table = T.Parsing()

# %%
T.clean()
T.extraction()

# %%
T.Link

# %%
T.link_go()
# Out:
# D:\Anaconda\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning

# %%
T.Link1
# Out:
# ['https://www.scimagojr.com/journalsearch.php?q=21100404576&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100447128&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100779062&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=145295&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=30787&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4000148019&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19374&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100776059&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=15286&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=100147335&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100454916&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=27488&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19700173246&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=15185&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=26493&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=16800154743&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17539&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=20031&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19900191906&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=20191&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=5200152701&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700152287&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=20206&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=24078&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19532&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18735&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=28034&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=200147123&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=130105&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=5000158708&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=28094&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=28096&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=22657&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=23415&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=25159&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=25161&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=23038&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19400157014&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700152798&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13683&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700153006&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12100154833&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12100154406&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100784666&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4800153205&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=23051&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12213&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=26199&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19700183047&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13044&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18662&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=10300153313&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=24972&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18997&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19700190323&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=15773&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=5800173377&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18120&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=23054&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700151918&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100832567&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=27836&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100217640&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700152843&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18121&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700152858&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=5800207369&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12922&tip=sid&clean=0',
#  None,
#  'https://www.scimagojr.com/journalsearch.php?q=19700171101&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100461927&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19700188320&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100824912&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=5300152227&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19700172804&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19700186746&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100832985&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100461918&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100209317&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19
tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100327726&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700151731&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18654&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12028&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12029&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100200437&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12041&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=40907&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=4700152623&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13852&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100829268&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18136&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=96119&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17400154814&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=23934&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29595&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=25195&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=28983&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13688&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=16724&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29417&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29419&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100198493&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29422&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29426&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29427&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17300154739&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=16728&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17182&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13043&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=16730&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=22006&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19144&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=20000195048&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29436&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12400154704&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19620&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=29034&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=24602&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17700156743&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13951&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19400158709&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17400154823&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19622&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19500157002&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=5000154401&tip=sid&clean=0',
#  None,
#  'https://www.scimagojr.com/journalsearch.php?q=86164&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=21100296203&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=25206&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19956&tip=sid&clean=0',
#  None,
#  'https://www.scimagojr.com/journalsearch.php?q=19339&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=25207&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=25208&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=16800154737&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=13952&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=97492&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=14402&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=14202&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12947&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=200147102&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=17657&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=16811&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=12300154711&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=11300153709&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=14000156254&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=14206&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=19274&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=18093&tip=sid&clean=0',
#  None,
#  'https://www.scimagojr.com/journalsearch.php?q=24250&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=14491&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=14492&tip=sid&clean=0',
#  'https://www.scimagojr.com/journalsearch.php?q=30081&tip=sid&clean=0',
#  ...]

# %%
fetch_url(T.Link[0])

# %%
T.Scope_Parsing(1,T.Link1[0])
# Out:
# :-(

# %%
T.Link1[0]
# Out:
# 'https://www.scimagojr.com/journalsearch.php?q=21100404576&tip=sid&clean=0'

# %%
response = urllib.request.urlopen(T.Link1[0]).read()
response
# Out:
# b'\r\n<html>\r\n  <head>\r\n <meta charset="UTF-8">\r\n \r\n  <title>2D Materials</title>\r\n  <meta name="viewport" content="width=device-width, user-scalable=no" />  \r\n  \r\n <link href=\'https://fonts.googleapis.com/css?family=Roboto:400,500,700\' rel=\'stylesheet\' type=\'text/css\' />\r\n  <link href=\'./gridcss/gridv2.css\' rel=\'stylesheet\' type=\'text/css\' />\r\n   <link href=\'./gridcss/sjr.css?2020\' rel=\'stylesheet\' type=\'text/css\' />\r\n   <link href=\'./gridcss/sjrjournal.css\' rel=\'stylesheet\' type=\'text/css\' />\r\n   <link href=\'./wp_comments_css/comments-styles.css\' rel=\'stylesheet\' type=\'text/css\' /><!-- WP Comments styles -->\r\n   <link href=\'./gridcss/comments.css\' rel=\'stylesheet\' type=\'text/css\' />\r\n\r\n <link rel="shortcut icon" href="favicon.ico" />\r\n <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\r\n<link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\r\n<link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\r\n<link rel="manifest" href="/site.webmanifest">\r\n<meta name="msapplication-TileColor" content="#da532c">\r\n<meta name="theme-color" content="#ffffff">\r\n\r\n<script src="./js/raceme.min.js"></script>\r\n  <script src="./js/papaparse.min.js"></script>\r\n  \r\n  <script src="./js/Dataset.min.js"></script>\r\n  <script src="./js/Axis.min.js"></script>\r\n  <script src="./js/Elements.min.js"></script>\r\n  <script src="./js/Frame.min.js"></script>\r\n  <script src="./js/Properties.min.js"></script>\r\n  <script src="./js/View.min.js"></script>\r\n  <script src="./js/Utils.min.js"></script>\r\n <!-- <script src="./js/Player.min.js"></script>-->\r\n  <script src="./js/Legend.min.js"></script>\r\n  <script src="./js/tooltip.min.js"></script>\r\n  <!--<script src="./js/cola.min.js"></script>-->\r\n\r\n\r\n \r\n <script src="./gridcss/gridv2.js"></script>\r\n <script src="./js/mainmenu.js"></script>\r\n <script src="./js/related_journals.js?v=2"></script>\r\n <script src="./js/dropdown.js?v=1"></script>\r\n  <script type="text/javascript">\r\n   main(function () {\r\n\r\n      if (by(\'id:join_conversation\')) {\r\n        by(\'id:join_conversation\').clic(function (e) {\r\n          e.preventDefault();\r\n          by(\'id:wp-comments-response\').animate(1000).ease(\'inout\').topOffset(0);\r\n          return false;\r\n        });\r\n      }\r\n        \r\n  \r\n        var settings_sjr={\r\n          general: {\r\n            padding:10,\r\n            default_shape:"none",\r\n            default_width:3,\r\n            default_area:400,\r\n            default_color:"rgb(231, 118, 66)"\r\n            \r\n          },  \r\n          grammar: [\r\n            {\r\n              variable:"Year",\r\n              property:"axis_x",\r\n              legend:false,\r\n              show_title:false,\r\n              show_ticks:false,\r\n              show_line:false,\r\n              padding:0\r\n            },\r\n            {\r\n              variable:"SJR",\r\n              property:"axis_y",\r\n              show_title:false,\r\n              show_ticks:false,\r\n              show_line:false,\r\n              show_grid_lines:true\r\n            },\r\n            {\r\n              variable:"Year",\r\n              property:"connection"\r\n            },\r\n            {\r\n              variable:"SJR",\r\n              property:"tooltip"\r\n            },\r\n            {\r\n              variable:"Year",\r\n              property:"tooltip",\r\n              tooltip_format:" ([value])"\r\n            }\r\n          ]\r\n        };\r\n\r\n        var settings_totaldocs={\r\n          general: {\r\n            padding:10,\r\n            default_shape:"none",\r\n            default_width:3,\r\n            default_area:400,\r\n            default_color:"rgb(122,195,106)"\r\n            \r\n          },  \r\n          grammar: [\r\n            {\r\n              variable:"Year",\r\n              property:"axi ...

# %%
soup = BS(response,'html.parser')
str(soup.find('div', class_='fullwidth').contents[2])
# Out:
# "\r\n      2D Materials aims to curate the most significant and cutting-edge research being undertaken in the field of 2D materials science and engineering. Serving an expanding multidisciplinary community of researchers and technologists, our goal is to develop a selective journal dedicated to bringing together the most important new results and perspectives from across the discipline. Submissions should be essential reading for a particular sub-field, but should also be of multidisciplinary interest to the wider community, with the expectation that published work will have significant impact.\r\n\r\nSubmissions that do not meet 2DM's strict acceptance criteria may be transferred at the discretion of the journal's editors (with author approval) to other relevant journals in the IOP portfolio, for further consideration.\r\n2D Materials is a multidisciplinary journal devoted to publishing original research of the highest quality and impact covering all aspects of two-dimensional materials, including fundamental properties (experiments, theory and simulations), novel applications (electrical, mechanical, chemical and biomedical) and synthesis/fabrication techniques. Specific materials of interest will include (but are not limited to):\r\n\r\nGraphene and graphene-derived materials (such as graphene oxides, graphene quantum dots etc)\r\nSilicene and germanene/silicane and germanane\r\nBoron nitride\r\nTransition metal dichalcogenides\r\n2D topological insulators\r\nComplex oxides\r\nComposite materials\r\nOther novel 2D layered structures\r\nIn addition to publishing research articles that report urgent breakthrough results of significant importance to the field of two-dimensional materials, 2D Materials also publishes Perspectives and invited-only Topical Reviews on themes of particular current interest to the community.        "

# %%
import multiprocessing
import time
from joblib import Parallel, delayed

# %%
def Link_Parsing(Link):
        try:
            response = urllib.request.urlopen(Link).read()
            soup = BS(response,'html.parser')
            return 'https://www.scimagojr.com/'+soup.find('div', class_='search_results').a['href']
            
        except:
            return None
def Scope_Parsing(url):
    try:
        response = urllib.request.urlopen(link).read()
        soup = BS(response,'html.parser')
        return(str(soup.find('div', class_='fullwidth').contents[2]))


    except:
      #print(url)
      #Notaccess.append(url)
      print(":-(")
      return (None)

# %%
inputs = range(100) 
def processInput(i):
    return i * i
 
num_cores = multiprocessing.cpu_count()
def fo(i,j):
    return Parallel(n_jobs = i)(delayed(processInput)(item) for item in j)
    
#results = Parallel(n_jobs=num_cores)(delayed(processInput)(i) for i in inputs)
fo(num_cores,inputs)

# %%
results

# %%
# square function
def fetch_url(url):
    try:
      urlHandler = urllib.request.urlopen(url)
      tmp=(urlHandler.read())
      #html.append('https://www.scimagojr.com/'+BeautifulSoup(tmp,'html.parser').find('div', class_='search_results').a['href'])

      print('*_*')
      return 'https://www.scimagojr.com/'+BS(tmp,'html.parser').find('div', class_='search_results').a['href']
    except:
      #print(url)
      #Notaccess.append(url)
      print(":-(")
      return (None)

# %%
num_cores = multiprocessing.cpu_count()
num_cores

# %%
def addition(n):
    return n + n
  
# We double all numbers using map()
numbers = [1, 2, 3, 4]
result = map(addition, numbers)

print(list(result))

# %%
if __name__ == '__main__':

	# multiprocessing pool object
	pool = multiprocessing.Pool()

	# pool object with number of element
	pool = multiprocessing.Pool(processes=5)

	# input list
	#inputs = list(range(10000))

	# map the function to the list and pass
	# function and input list as arguments
	outputs = pool.map(fetch_url, T.Link[0:10])

	# Print input list
#	print("Input: {}".format(T.Link[0:10]))

	# Print output list
#	print("Output: {}".format(outputs))

# %%
from multiprocessing import Pool

# %%
def f(x):
    return x*x


with Pool(5) as p:
        print(p.map(f, [1, 2, 3,4,7]))

# %%
from multiprocessing import Process

def f(name):
    print('hello', name)

if __name__ == '__main__':
    p = Process(target=f, args=('bob',))
    p.start()
    p.join()

# %% [markdown]
# # importing the multiprocessing module
# import multiprocessing
# import os
#
# def worker1():
#     print("Worker 1")
#     print("ID of process running worker1: {}".format(os.getpid()))
#
# def worker2():
#     print("Worker 2")
#     print("ID of process running worker2: {}".format(os.getpid()))
#
# if __name__ == "__main__":
#     print("ID of main process: {}".format(os.getpid()))
#
#     p1 = multiprocessing.Process(target=worker1)
#     p2 = multiprocessing.Process(target=worker2)
#     p1.start()
#     p2.start()
#     print("ID of process p1: {}".format(p1.pid))
#     print("ID of process p2: {}".format(p2.pid))
#
#     # wait until processes are finished
#     p1.join()
#     p2.join()
#
#     # both processes finished
#     print("Both processes finished execution!")
#
#     print("Process p1 is alive: {}".format(p1.is_alive()))
#     print("Process p2 is alive: {}".format(p2.is_alive()))

# %%
T.Link

# %%
T.Link[0]

# %%
Parsing1(T.Link[0])

# %% [markdown]
# ### Cleaning Certain rows and renaming column as follows

# %%
table.rename(columns = table.iloc[2],inplace=True)
table = table.drop(labels=[0,1,2],axis = 0)
table.head()

# %%
table

# %%
Page = requests.get(URL1)
soup = BS(Page.content,'html.parser')
soup

# %%
Table  = soup.find('table',{"class":"myTable"})
Table

# %%
Table_Data = []
for row in Table.find_all('tr'):
    tmp = []
    column = row.find_all('td')
    for index in range(len(column)):
        tmp.append(column[index].text.strip())
    Table_Data.append(tmp)
    #print(len(column))

# %%
X = pd.DataFrame(Table_Data)

# %%
columnName = X.iloc[2]

# %%
columnName

# %%
print(X)
columnName = X.iloc[2]
Y = X.drop(X.iloc[0:2])

# %%
X.columns

# %%
X.columns

# %%
X[2]

# %%
ISSN = X[2]

# %%
ISSN = [i.split('\n')[0] for i in ISSN[2:]]
ISSN

# %%
for i in ISSN[3:10]:
  print(i.split('\n')[0])

# %%
ISSN[10].split('\n')[0]
